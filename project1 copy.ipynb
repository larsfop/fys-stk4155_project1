# %%
import numpy as np
import numpy.typing as npt
import matplotlib.pyplot as plt
import pandas as pd
from imageio import imread
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MinMaxScaler, MaxAbsScaler, RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model._base import BaseEstimator

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from random import random, seed

# %matplotlib widget

rng = np.random.default_rng(125)

# %%
# 2D design matrix
# omit y for a 1D design matrix
def DesignMatrix(p_order: int, x: npt.ArrayLike, y: npt.ArrayLike = None, intercept: bool = True) -> npt.NDArray:
    """
    Produce a Design matrix for linear regression for a given polynomial order in 1d or omit y for 2d

    Parameters:
        p_order (int): Order of polynomial
        x (ArrayLike): Array to be used in the Design matrix
        y (ArrayLike, optional): Add this parameter for 2d Design matrix, leave empty for 1d
        intercept (bool, optional): Wether the intercept should be included in the Design matrix, if False remove the first parameter
    """
    if y.any() != None:
        X = np.ones((len(x), 1))
        for k in range(1, p_order+1):
            j = k
            i = 0
            while i < k + 1:
                X = np.column_stack((X, x**i*y**j))
                # if i == j:
                #     X = np.column_stack((X, x**i*y**j))
                # else:
                #     X = np.column_stack((X, x**i*y**j))
                #     X = np.column_stack((X, y**i*x**j))
                j -= 1
                i += 1
    
    else:
        X = np.ones((len(x), p_order+1))
        for i in range(1, p_order+1):
            X[:,i] = x**i

    if not intercept:
        X = np.delete(X, 0, 1)

    return X
    # 1                     #0 == 1  
    # x,y                   #1 == 3  
    # x²,y²,xy              #2 == 6  
    # x³,y³,yx²,xy²         #3 == 10
    # x⁴,y⁴,yx³,xy³,x²y²    #4 == 15 
    
    # 1,
    # 2, 2
    # 4, 4, 4
    # 8, 8, 8, 8
    # 16, 16, 16, 16, 16


def FrankeFunction(x: npt.ArrayLike, y: npt.ArrayLike, noise_factor: int=0) -> npt.NDArray:
    np.random.seed(125)
    
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return term1 + term2 + term3 + term4 + noise_factor*np.random.normal(0, 1, x.shape)


def R2(y_data: npt.ArrayLike, y_model: npt.ArrayLike) -> float:
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)


def MSE(y_data: npt.ArrayLike,y_model: npt.ArrayLike) -> float:
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n

# %%
def Plot(x, y, *z):
    n = len(z)
    fig, axs = plt.subplots(1, n, subplot_kw={"projection" : "3d"})

    for i in range(n):
        surf = axs[i].plot_surface(x, y, z[i], cmap=cm.coolwarm,
                        linewidth=0, antialiased=False)

        # Add a color bar which maps values to colors.
        fig.colorbar(surf, shrink=0.5, aspect=5)
    fig.legend()

    plt.show()

# %%
x = np.array([2,2])
y = np.array([3,3])
X = DesignMatrix(5, x, y, intercept=False)
n = lambda x : int(((x + 2)*(x + 1))/2)
p = 2
print(X[:,:int(((p + 2)*(p + 1))/2)])
# Out:
# [[ 3.  2.  9.  6.  4. 27.]
#  [ 3.  2.  9.  6.  4. 27.]]

# %%
fig, ax = plt.subplots(subplot_kw={"projection" : "3d"})

n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)
x, y = np.meshgrid(x,y)

z = FrankeFunction(x, y, False)

# Plot the surface.
surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-0.10, 1.40)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Ordinary Linear Square Regression

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

X = DesignMatrix(1, x, y)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0)

X_train, X_test, y_train, y_test = train_test_split(X, z, test_size=0.2, random_state=125)

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

scaler.fit(y_train)
y_train_scaled = scaler.transform(y_train)
y_test_scaled = scaler.transform(y_test)


beta = (np.linalg.pinv(X_train.T @ X_train) @ X_train.T ) @ y_train
print('Unscaled data')
y_fit = X_train @ beta
print(f'Training fit:\n   MSE = {MSE(y_train, y_fit)} ; R2 = {R2(y_train, y_fit)}')

y_pred = X_test @ beta
print(f'Test fit:\n   MSE = {MSE(y_test, y_pred)} ; R2 = {R2(y_test, y_pred)}')

beta_scaled = (np.linalg.pinv(X_train_scaled.T @ X_train_scaled) @ X_train_scaled.T ) @ y_train_scaled
print('\nScaled data')
y_fit_scaled = X_train_scaled @ beta_scaled
print(f'Training fit:\n   MSE = {MSE(y_train_scaled, y_fit_scaled)} ; R2 = {R2(y_train_scaled, y_fit_scaled)}')

y_pred_scaled = X_test_scaled @ beta_scaled
print(f'Test fit:\n   MSE = {MSE(y_test_scaled, y_pred_scaled)} ; R2 = {R2(y_test_scaled, y_pred_scaled)}')

Plot(x, y, X@beta, z)

fig, axs = plt.subplots(1,2, sharey=True, sharex=True)

axs[0].imshow(X@beta, cmap=cm.coolwarm, origin='lower')
axs[1].imshow(z, cmap=cm.coolwarm, origin='lower')
axs[0].set_xlabel('X')
axs[1].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[0].set_title('Fitted data')
axs[1].set_title('Real data')
# Out:
# Unscaled data
# Training fit:
#    MSE = 0.012642519635972726 ; R2 = 0.8531181494859871
# Test fit:
#    MSE = 0.012967914001652403 ; R2 = 0.7982434710171993
#
# Scaled data
# Training fit:
#    MSE = 0.28624962539648263 ; R2 = 0.7137503746035174
# Test fit:
#    MSE = 0.29070448435226726 ; R2 = 0.640950914143428
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Real data')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Ridge Regression

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

X = DesignMatrix(5, x, y)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0)

p = X.shape[1]
I = np.eye(p, p)
lambdas = np.logspace(-8, 1, n)

X_train, X_test, y_train, y_test = train_test_split(X, z, test_size=0.2, random_state=125)

scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# scaler.fit(y_train)
# y_train = scaler.transform(y_train)
# y_test = scaler.transform(y_test)

MSE_train = []
MSE_test = []
MSE_train_ridge = []
MSE_test_ridge = []
for lmb in lambdas:
    beta = np.linalg.pinv(X_train.T @ X_train + lmb*I) @ X_train.T @ y_train
    y_fit = X_train @ beta
    y_pred = X_test @ beta

    MSE_train.append(MSE(y_train, y_fit))
    MSE_test.append(MSE(y_test, y_pred))

    ridge = linear_model.Ridge(alpha=lmb, fit_intercept=False)
    ridge.fit(X_train, y_train)

    y_fit = ridge.predict(X_train)
    y_pred = ridge.predict(X_test)

    MSE_train_ridge.append(MSE(y_train, y_fit))
    MSE_test_ridge.append(MSE(y_test, y_pred))

    # print(f'Training fit:\n   MSE = {MSE(y_train, y_fit)} ; R2 = {R2(y_train, y_fit)}')
    # print(f'Test fit:\n   MSE = {MSE(y_test, y_pred)} ; R2 = {R2(y_test, y_pred)}')

plt.figure()

plt.plot(lambdas, MSE_train, label='Training data')
plt.plot(lambdas, MSE_test, label='Test data')
plt.plot(lambdas, MSE_train_ridge, label='Ridge Test data', linestyle='--')
plt.plot(lambdas, MSE_test_ridge, label='Ridge Test data', linestyle='--')
plt.xscale('log')
plt.xlabel('lambda')
plt.ylabel('MSE')
plt.grid()
plt.legend()

plt.show()

ridge = linear_model.Ridge(alpha=1e-4, fit_intercept=False)
ridge.fit(X_train, y_train)
beta = ridge.coef_
beta = np.swapaxes(beta, 0, 1)

y_fit = ridge.predict(X_train)
y_pred = ridge.predict(X_test)

Plot(x, y, X@beta, z)

fig, axs = plt.subplots(1,2, sharey=True, sharex=True)

axs[0].imshow(X@beta, cmap=cm.coolwarm, origin='lower')
axs[1].imshow(z, cmap=cm.coolwarm, origin='lower')
axs[0].set_xlabel('X')
axs[1].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[0].set_title('Fitted data')
axs[1].set_title('Real data')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Real data')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Lasso Regression

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

X = DesignMatrix(5, x, y)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0.1)

p = X.shape[1]
I = np.eye(p, p)
lambdas = np.logspace(-8, 0, 10)

X_train, X_test, y_train, y_test = train_test_split(X, z, test_size=0.2, random_state=125)

scaler = StandardScaler()
scaler.fit(X_train)

"""X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

scaler.fit(y_train)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)"""

MSE_train = []
MSE_test = []
for lmb in lambdas:
    reg = linear_model.Lasso(lmb, fit_intercept=False)
    reg.fit(X_train, y_train)

    y_fit = reg.predict(X_train)
    y_pred = reg.predict(X_test)

    MSE_train.append(MSE(y_train, y_fit))
    MSE_test.append(MSE(y_test, y_pred))

    # print(f'Training fit:\n   MSE = {MSE(y_train, y_fit)} ; R2 = {R2(y_train, y_fit)}')
    # print(f'Test fit:\n   MSE = {MSE(y_test, y_pred)} ; R2 = {R2(y_test, y_pred)}')

plt.figure()

plt.plot(lambdas, MSE_train, label='Training data')
plt.plot(lambdas, MSE_test, label='Test data')
plt.xscale('log')
plt.xlabel('lambda')
plt.ylabel('MSE')
plt.grid()
plt.legend()

plt.show()

reg = linear_model.Lasso(lambdas[2], fit_intercept=False)
reg.fit(X_train, y_train)

beta = reg.coef_
beta = np.swapaxes(beta, 0, 1)

y_fit = reg.predict(X_train)
y_pred = reg.predict(X_test)

Plot(x, y, X@beta, z)

fig, axs = plt.subplots(1,2, sharey=True, sharex=True)

axs[0].imshow(X@beta, cmap=cm.coolwarm, origin='lower')
axs[1].imshow(z, cmap=cm.coolwarm, origin='lower')
axs[0].set_xlabel('X')
axs[1].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[0].set_title('Fitted data')
axs[1].set_title('Real data')
# Out:
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.172e-01, tolerance: 3.073e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.252e-01, tolerance: 3.013e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.082e-01, tolerance: 3.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.355e-01, tolerance: 3.281e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.873e-01, tolerance: 3.436e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.629e-01, tolerance: 3.513e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.393e-01, tolerance: 3.394e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.114e-01, tolerance: 3.783e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.604e-01, tolerance: 4.098e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.375e-01, tolerance: 4.005e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.558e-01, tolerance: 4.105e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.478e-01, tolerance: 4.367e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.936e-01, tolerance: 4.331e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.659e-01, tolerance: 4.229e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.104e-01, tolerance: 4.385e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.467e-01, tolerance: 4.909e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.595e-01, tolerance: 4.688e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.506e-01, tolerance: 4.586e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.254e-01, tolerance: 4.713e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.396e-01, tolerance: 4.690e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.597e-01, tolerance: 4.855e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.646e-01, tolerance: 5.039e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.085e-01, tolerance: 4.452e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.406e-01, tolerance: 4.828e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.977e-01, tolerance: 4.656e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.178e-01, tolerance: 4.537e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.579e-01, tolerance: 4.529e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.468e-01, tolerance: 4.348e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.094e-01, tolerance: 4.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.307e-01, tolerance: 3.727e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.273e-01, tolerance: 3.829e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.389e-01, tolerance: 3.544e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.179e-01, tolerance: 3.347e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.784e-01, tolerance: 3.259e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.960e-01, tolerance: 3.003e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.117e-01, tolerance: 3.003e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.232e-01, tolerance: 2.754e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.295e-01, tolerance: 2.567e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.823e-01, tolerance: 2.465e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.026e-01, tolerance: 2.123e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.319e-01, tolerance: 2.115e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.601e-01, tolerance: 1.892e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.811e-01, tolerance: 1.762e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.185e-01, tolerance: 1.626e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.987e-01, tolerance: 1.483e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.164e-01, tolerance: 1.287e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.528e-01, tolerance: 1.397e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.248e-01, tolerance: 1.437e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.992e-01, tolerance: 1.164e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.789e-01, tolerance: 1.061e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.369e-01, tolerance: 1.098e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.022e-01, tolerance: 9.764e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e-01, tolerance: 1.062e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.082e-01, tolerance: 9.205e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.050e-01, tolerance: 1.037e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.661e-01, tolerance: 1.072e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.512e-01, tolerance: 1.103e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.194e-01, tolerance: 1.025e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.456e-01, tolerance: 9.765e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.194e-01, tolerance: 1.094e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.885e-01, tolerance: 9.347e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.963e-01, tolerance: 1.058e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.457e-01, tolerance: 1.051e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.195e-01, tolerance: 1.134e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.786e-01, tolerance: 1.114e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.088e-01, tolerance: 1.188e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.641e-01, tolerance: 1.254e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.852e-01, tolerance: 1.125e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.510e-01, tolerance: 1.186e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.148e-01, tolerance: 1.270e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.976e-01, tolerance: 1.295e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.317e-01, tolerance: 1.292e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.100e-01, tolerance: 1.335e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.733e-01, tolerance: 1.352e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.468e-01, tolerance: 1.285e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.114e-01, tolerance: 1.262e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.789e-01, tolerance: 1.223e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.432e-01, tolerance: 1.342e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.595e-01, tolerance: 1.281e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.354e-01, tolerance: 1.274e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.187e-01, tolerance: 1.039e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.581e-01, tolerance: 1.122e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.498e-01, tolerance: 1.265e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.705e-01, tolerance: 1.059e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.020e-01, tolerance: 9.094e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.694e-01, tolerance: 8.861e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.346e-01, tolerance: 8.526e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.682e-01, tolerance: 7.654e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.470e-01, tolerance: 6.572e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.768e-01, tolerance: 6.770e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.660e-01, tolerance: 6.480e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e-01, tolerance: 5.164e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.141e-01, tolerance: 4.508e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.527e-01, tolerance: 4.467e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.887e-01, tolerance: 4.227e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.380e-01, tolerance: 3.987e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.395e-01, tolerance: 4.008e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.927e-01, tolerance: 3.272e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.811e-01, tolerance: 2.995e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.712e-01, tolerance: 2.999e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.167e-01, tolerance: 3.073e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.248e-01, tolerance: 3.013e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.078e-01, tolerance: 3.000e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.352e-01, tolerance: 3.281e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.869e-01, tolerance: 3.436e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.626e-01, tolerance: 3.513e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.389e-01, tolerance: 3.394e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.109e-01, tolerance: 3.783e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.600e-01, tolerance: 4.098e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.372e-01, tolerance: 4.005e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.555e-01, tolerance: 4.105e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.475e-01, tolerance: 4.367e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.933e-01, tolerance: 4.331e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.656e-01, tolerance: 4.229e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.100e-01, tolerance: 4.385e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.464e-01, tolerance: 4.909e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.592e-01, tolerance: 4.688e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.504e-01, tolerance: 4.586e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.252e-01, tolerance: 4.713e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.392e-01, tolerance: 4.690e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.595e-01, tolerance: 4.855e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.644e-01, tolerance: 5.039e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e-01, tolerance: 4.452e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.403e-01, tolerance: 4.828e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.974e-01, tolerance: 4.656e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.176e-01, tolerance: 4.537e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.576e-01, tolerance: 4.529e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.465e-01, tolerance: 4.348e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.091e-01, tolerance: 4.400e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.304e-01, tolerance: 3.727e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.271e-01, tolerance: 3.829e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.387e-01, tolerance: 3.544e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.175e-01, tolerance: 3.347e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.781e-01, tolerance: 3.259e-03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.059e-01, tolerance: 1.025e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.295e-01, tolerance: 9.765e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.133e-01, tolerance: 1.094e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.753e-01, tolerance: 9.347e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.918e-01, tolerance: 1.058e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.391e-01, tolerance: 1.051e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.051e-01, tolerance: 1.134e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.723e-01, tolerance: 1.114e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.712e-01, tolerance: 1.188e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.371e-01, tolerance: 1.254e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.743e-01, tolerance: 1.125e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.404e-01, tolerance: 1.186e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.091e-01, tolerance: 1.270e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.856e-01, tolerance: 1.295e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.217e-01, tolerance: 1.292e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.044e-01, tolerance: 1.335e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.612e-01, tolerance: 1.352e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.405e-01, tolerance: 1.285e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.068e-01, tolerance: 1.262e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.745e-01, tolerance: 1.223e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.316e-01, tolerance: 1.342e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.409e-01, tolerance: 1.281e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.182e-01, tolerance: 1.274e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.091e-01, tolerance: 1.039e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.498e-01, tolerance: 1.122e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.398e-01, tolerance: 1.265e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.608e-01, tolerance: 1.059e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.901e-01, tolerance: 9.094e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.646e-01, tolerance: 8.861e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.263e-01, tolerance: 8.526e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.537e-01, tolerance: 7.654e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.417e-01, tolerance: 6.572e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.530e-01, tolerance: 6.770e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.571e-01, tolerance: 6.480e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.287e-01, tolerance: 5.164e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.077e-01, tolerance: 4.508e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.449e-01, tolerance: 4.467e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.823e-01, tolerance: 4.227e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.247e-01, tolerance: 3.987e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.353e-01, tolerance: 4.008e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.642e-01, tolerance: 3.272e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.734e-01, tolerance: 2.995e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/lars/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.634e-01, tolerance: 2.999e-04
#   model = cd_fast.enet_coordinate_descent(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 1.0, 'Real data')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Cross Validation

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

X = DesignMatrix(5, x, y)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0.1)

lambdas = np.logspace(-8, 3, n)

X_train, X_test, y_train, y_test = train_test_split(X, z, test_size=0.2, random_state=125)

k = 5
model = make_pipeline(
    #andardScaler(),
    linear_model.LinearRegression(fit_intercept=False),
    linear_model.Ridge(fit_intercept=False),
    linear_model.Lasso(fit_intercept=False),
    KFold(n_splits=k),
)
print(model.named_steps['test'])

mse = []
for lmb in lambdas:
    ridge = model.named_steps['ridge'].set_params(alpha=lmb)
        
    cv = cross_val_score(ridge, X, z, scoring='neg_mean_squared_error', cv=k)
    # print(lmb, np.mean(-cv), cv)
    mse.append(np.mean(-cv))
    
plt.figure()

plt.plot(lambdas, mse)
plt.xscale('log')
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 23
#      15 k = 5
#      16 model = make_pipeline(
#      17     #andardScaler(),
#      18     linear_model.LinearRegression(fit_intercept=False),
#    (...)
#      21     KFold(n_splits=k),
#      22 )
# ---> 23 print(model.named_steps['test'])
#      25 mse = []
#      26 for lmb in lambdas:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_bunch.py:39, in Bunch.__getitem__(self, key)
#      34 if key in self.__dict__.get("_deprecated_key_to_warnings", {}):
#      35     warnings.warn(
#      36         self._deprecated_key_to_warnings[key],
#      37         FutureWarning,
#      38     )
# ---> 39 return super().__getitem__(key)
#
# KeyError: 'test'

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

p = 5
X = DesignMatrix(p, x, y)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0)

lambdas = np.logspace(-8, 1, n)

k = 10

param_grid = {
    'alpha': lambdas
}

clf = GridSearchCV(linear_model.Ridge(fit_intercept=False), param_grid=param_grid, cv=k, scoring='neg_mean_squared_error', n_jobs=8)
clf.fit(X, z)

print('Best model:')
print(f'   Best lambda: {clf.best_params_["alpha"]:.5e}')
print(f'   Best MSE:    {-clf.best_score_:.5f}')
print(f'   CV score:    {-np.mean(cross_val_score(clf.best_estimator_, X, z, scoring="neg_mean_squared_error", cv=k)):.5f}')

# y_pred = clf.predict(X_test)

cv_results = clf.cv_results_
lambdas = cv_results['param_alpha']
mse = -cv_results['mean_test_score']

fig, ax = plt.subplots()

ax.plot(lambdas, mse)
ax.set_xscale('log')
# ax.set_yscale('log')
ax.grid()
# Out:
# Best model:
#    Best lambda: 2.84804e-05
#    Best MSE:    0.00505
#    CV score:    0.00505
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## GridSearch

# %%
class Estimator(BaseEstimator):
    def __init__(self, p: int = 1, lmbda: float = None, lin_reg = 'OLS'):
        """
            Custom estimator for GridSearchCV. Takes in lists or arrays for the polynomial order p and lambdas. Only works for X inputs where X is a 2d polynomial design matrix of order p.
            
            Parameters:
                p (int) : The order of polynomial for the design matrix.
                lmbda (float, optional) : The lambda value for Ridge and Lasso regression, default value is None. Required for Ridge and Lasso.
                lin_reg (str, linear_model) : String value for the implemented regression models (OLS, Ridge, Lasso), can also just be a regression model from sci-kit learn, though the estimator is quite simple and will probably not work with a different model.
        """
        self.p = p
        self.lmbda = lmbda
        
        if lin_reg == 'OLS':
            self.lin_reg = linear_model.LinearRegression(fit_intercept=False)
        elif lin_reg == 'Ridge':
            self.lin_reg = linear_model.Ridge(fit_intercept=False)
        elif lin_reg == 'Lasso':
            self.lin_reg = linear_model.Lasso(fit_intercept=False)
        else:
            self.lin_reg = lin_reg
            
    def fit(self, x, y):
        # Sets the lambda value if it is given as a parameter, if not default to what sci-kit learn have set
        if self.lmbda != None:
            self.lin_reg.set_params(alpha=self.lmbda)
        # an integer for picking the correct slice from the x values.
        n = int(((self.p + 2)*(self.p + 1))/2)
        x_ = x[:,:n]
        # print(self.p, n, x_.shape)
        self.lin_reg.fit(x_, y)
        
        return self
    
    def predict(self, x):
        n = int(((self.p + 2)*(self.p + 1))/2)
        x_ = x[:,:n]
        return self.lin_reg.predict(x_)

# %%
n = 100
# Make data.
x = np.linspace(0, 1, n)
y = np.linspace(0, 1, n)

p = 10
X = DesignMatrix(p, x, y)
print(X.shape)

x, y = np.meshgrid(x, y)
z = FrankeFunction(x, y, 0)

lambdas = np.logspace(-8, 1, n)

k = 10

param_grid = {
    'p': [5],# np.arange(p+1),
    'lmbda': lambdas,
}

clf = GridSearchCV(Estimator(lin_reg='Ridge'), param_grid=param_grid, cv=k, scoring='neg_mean_squared_error', n_jobs=8)
clf.fit(X, z)

print('Best model:')
print(f'   Best p:      {clf.best_params_["p"]}')
print(f'   Best lambda: {clf.best_params_["lmbda"]:.5e}')
print(f'   Best MSE:    {-clf.best_score_:.5f}')
print(f'   CV score:    {-np.mean(cross_val_score(clf.best_estimator_, X, z, scoring="neg_mean_squared_error", cv=k)):.5f}')

# y_pred = clf.predict(X_test)

cv_results = clf.cv_results_
#display(pd.DataFrame(cv_results))
lambdas = cv_results['param_lmbda']
ps = cv_results['param_p']
mse = -cv_results['mean_test_score']

fig, ax = plt.subplots()

# for i in range(p+1):
#     ax.plot(lambdas[i::p+1], mse[i::p+1], label=f'p = {i}')
ax.plot(lambdas, mse)
ax.set_xscale('log')
# ax.set_yscale('log')
plt.legend()
ax.grid()
# Out:
# (100, 66)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Best model:
#    Best p:      5
#    Best lambda: 2.84804e-05
#    Best MSE:    0.00505
#    CV score:    0.00505
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import numpy as np
from imageio import imread
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig, axs = plt.subplots(1,2, sharey=True, sharex=True)

# Load the terrain
terrain1 = imread('SRTM_data_Norway_1.tif')
terrain2 = imread('SRTM_data_Norway_2.tif')
# Show the terrain
fig.suptitle('Terrain over Norway')
axs[0].imshow(terrain1, cmap='gray', origin='lower')
axs[1].imshow(terrain2, cmap='gray', origin='lower')
axs[0].set_xlabel('X')
axs[1].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[0].set_title('Terrain 1')
axs[1].set_title('Terrain 2')

plt.show()
# Out:
# /tmp/ipykernel_4762/3808675080.py:10: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   terrain1 = imread('SRTM_data_Norway_1.tif')
# /tmp/ipykernel_4762/3808675080.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   terrain2 = imread('SRTM_data_Norway_2.tif')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def create_X(x, y, n ):
	if len(x.shape) > 1:
		x = np.ravel(x)
		y = np.ravel(y)

	N = len(x)
	l = int((n+1)*(n+2)/2)		# Number of elements in beta
	X = np.ones((N,l))

	for i in range(1,n+1):
		q = int((i)*(i+1)/2)
		for k in range(i+1):
			X[:,q+k] = (x**(i-k))*(y**k)

	return X

# %%
yn, xn = terrain1.shape
n = yn
p = 48

x = np.sort(rng.uniform(0, 1, n))
y = np.sort(rng.uniform(0, 1, n))

# x = np.arange(0, n, 1)
# y = np.arange(0, n, 1)

X = DesignMatrix(p, x, y)

X_train, X_test, y_train, y_test = train_test_split(X, terrain1, test_size=0.2, random_state=125)

scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

scaler.fit(y_train)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

reg = linear_model.LinearRegression(fit_intercept=False)
reg.fit(X_train, y_train)

# sklearn linear regression takes the second axis as features, sklearn will then make a new regression for each feature.
# Therefore when we input a 2d dataset we will make a new regression for each row
beta = np.swapaxes(reg.coef_, 0, 1)

fig, axs = plt.subplots(1,2, sharey=True, sharex=True)

axs[0].imshow(X @ beta, cmap='gray', origin='lower')
axs[1].imshow(terrain1, cmap='gray', origin='lower')
axs[0].set_xlabel('X')
axs[1].set_xlabel('X')
axs[0].set_ylabel('Y')

axs[0].set_title('Fitted data')
axs[1].set_title('Real data')
# Out:
# /tmp/ipykernel_4762/3157071022.py:31: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(1,2, sharey=True, sharex=True)
# Text(0.5, 1.0, 'Real data')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = np.arange(0, terrain1.shape[0], 1)
y = np.arange(terrain1.shape[1], 0, -1)

x, y = np.meshgrid(y, x)

fig, ax = plt.subplots(subplot_kw={"projection" : "3d"})

# Plot the surface.
surf = ax.plot_surface(x, y, terrain2, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
#ax.set_zlim(-0.10, 1.40)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

ax.set_xlabel('X')
ax.set_ylabel('Y')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
